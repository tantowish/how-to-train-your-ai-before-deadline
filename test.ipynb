# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./Tetuan City power consumption.csv')
df
# Out:
#                DateTime  Temperature  Humidity  Wind Speed  \
# 0         1/1/2017 0:00        6.559      73.8       0.083
# 1         1/1/2017 0:10        6.414      74.5       0.083
# 2         1/1/2017 0:20        6.313      74.5       0.080
# 3         1/1/2017 0:30        6.121      75.0       0.083
# 4         1/1/2017 0:40        5.921      75.7       0.081
# ...                 ...          ...       ...         ...
# 52411  12/30/2017 23:10        7.010      72.4       0.080
# 52412  12/30/2017 23:20        6.947      72.6       0.082
# 52413  12/30/2017 23:30        6.900      72.8       0.086
# 52414  12/30/2017 23:40        6.758      73.0       0.080
# 52415  12/30/2017 23:50        6.580      74.1       0.081
#
#        general diffuse flows  diffuse flows  Zone 1 Power Consumption  \
# 0                      0.051          0.119               34055.69620
# 1                      0.070          0.085               29814.68354
# 2                      0.062          0.100               29128.10127
# 3                      0.091          0.096               28228.86076
# 4                      0.048          0.085               27335.69620
# ...                      ...            ...                       ...
# 52411                  0.040          0.096               31160.45627
# 52412                  0.051          0.093               30430.41825
# 52413                  0.084          0.074               29590.87452
# 52414                  0.066          0.089               28958.17490
# 52415                  0.062          0.111               28349.80989
#
#        Zone 2  Power Consumption  Zone 3  Power Consumption
# 0                    16128.87538                20240.96386
# 1                    19375.07599                20131.08434
# 2                    19006.68693                19668.43373
# 3                    18361.09422                18899.27711
# 4                    17872.34043                18442.40964
# ...                          ...                        ...
# 52411                26857.31820                14780.31212
# 52412                26124.57809                14428.81152
# 52413                25277.69254                13806.48259
# 52414                24692.23688                13512.60504
# 52415                24055.23167                13345.49820
#
# [52416 rows x 9 columns]

# %%
df.head()
# Out:
#         DateTime  Temperature  Humidity  Wind Speed  general diffuse flows  \
# 0  1/1/2017 0:00        6.559      73.8       0.083                  0.051
# 1  1/1/2017 0:10        6.414      74.5       0.083                  0.070
# 2  1/1/2017 0:20        6.313      74.5       0.080                  0.062
# 3  1/1/2017 0:30        6.121      75.0       0.083                  0.091
# 4  1/1/2017 0:40        5.921      75.7       0.081                  0.048
#
#    diffuse flows  Zone 1 Power Consumption  Zone 2  Power Consumption  \
# 0          0.119               34055.69620                16128.87538
# 1          0.085               29814.68354                19375.07599
# 2          0.100               29128.10127                19006.68693
# 3          0.096               28228.86076                18361.09422
# 4          0.085               27335.69620                17872.34043
#
#    Zone 3  Power Consumption
# 0                20240.96386
# 1                20131.08434
# 2                19668.43373
# 3                18899.27711
# 4                18442.40964

# %%
df.tail()
# Out:
#                DateTime  Temperature  Humidity  Wind Speed  \
# 52411  12/30/2017 23:10        7.010      72.4       0.080
# 52412  12/30/2017 23:20        6.947      72.6       0.082
# 52413  12/30/2017 23:30        6.900      72.8       0.086
# 52414  12/30/2017 23:40        6.758      73.0       0.080
# 52415  12/30/2017 23:50        6.580      74.1       0.081
#
#        general diffuse flows  diffuse flows  Zone 1 Power Consumption  \
# 52411                  0.040          0.096               31160.45627
# 52412                  0.051          0.093               30430.41825
# 52413                  0.084          0.074               29590.87452
# 52414                  0.066          0.089               28958.17490
# 52415                  0.062          0.111               28349.80989
#
#        Zone 2  Power Consumption  Zone 3  Power Consumption
# 52411                26857.31820                14780.31212
# 52412                26124.57809                14428.81152
# 52413                25277.69254                13806.48259
# 52414                24692.23688                13512.60504
# 52415                24055.23167                13345.49820

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
df.describe()
# Out:
#         Temperature      Humidity    Wind Speed  general diffuse flows  \
# count  52416.000000  52416.000000  52416.000000           52416.000000
# mean      18.810024     68.259518      1.959489             182.696614
# std        5.815476     15.551177      2.348862             264.400960
# min        3.247000     11.340000      0.050000               0.004000
# 25%       14.410000     58.310000      0.078000               0.062000
# 50%       18.780000     69.860000      0.086000               5.035500
# 75%       22.890000     81.400000      4.915000             319.600000
# max       40.010000     94.800000      6.483000            1163.000000
#
#        diffuse flows  Zone 1 Power Consumption  Zone 2  Power Consumption  \
# count   52416.000000              52416.000000               52416.000000
# mean       75.028022              32344.970564               21042.509082
# std       124.210949               7130.562564                5201.465892
# min         0.011000              13895.696200                8560.081466
# 25%         0.122000              26310.668692               16980.766032
# 50%         4.456000              32265.920340               20823.168405
# 75%       101.000000              37309.018185               24713.717520
# max       936.000000              52204.395120               37408.860760
#
#        Zone 3  Power Consumption
# count               52416.000000
# mean                17835.406218
# std                  6622.165099
# min                  5935.174070
# 25%                 13129.326630
# 50%                 16415.117470
# 75%                 21624.100420
# max                 47598.326360

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52416 entries, 0 to 52415
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   DateTime                   52416 non-null  object
#  1   Temperature                52416 non-null  float64
#  2   Humidity                   52416 non-null  float64
#  3   Wind Speed                 52416 non-null  float64
#  4   general diffuse flows      52416 non-null  float64
#  5   diffuse flows              52416 non-null  float64
#  6   Zone 1 Power Consumption   52416 non-null  float64
#  7   Zone 2  Power Consumption  52416 non-null  float64
#  8   Zone 3  Power Consumption  52416 non-null  float64
# dtypes: float64(8), object(1)
# memory usage: 3.6+ MB

# %%
df_excluded = df.drop(columns=['DateTime'])

df_excluded.corr()
# Out:
#                            Temperature  Humidity  Wind Speed  \
# Temperature                   1.000000 -0.460243    0.477109
# Humidity                     -0.460243  1.000000   -0.135853
# Wind Speed                    0.477109 -0.135853    1.000000
# general diffuse flows         0.460294 -0.468138    0.133733
# diffuse flows                 0.196522 -0.256886   -0.000972
# Zone 1 Power Consumption      0.440221 -0.287421    0.167444
# Zone 2  Power Consumption     0.382428 -0.294961    0.146413
# Zone 3  Power Consumption     0.489527 -0.233022    0.278641
#
#                            general diffuse flows  diffuse flows  \
# Temperature                             0.460294       0.196522
# Humidity                               -0.468138      -0.256886
# Wind Speed                              0.133733      -0.000972
# general diffuse flows                   1.000000       0.564718
# diffuse flows                           0.564718       1.000000
# Zone 1 Power Consumption                0.187965       0.080274
# Zone 2  Power Consumption               0.157223       0.044667
# Zone 3  Power Consumption               0.063376      -0.038506
#
#                            Zone 1 Power Consumption  \
# Temperature                                0.440221
# Humidity                                  -0.287421
# Wind Speed                                 0.167444
# general diffuse flows                      0.187965
# diffuse flows                              0.080274
# Zone 1 Power Consumption                   1.000000
# Zone 2  Power Consumption                  0.834519
# Zone 3  Power Consumption                  0.750733
#
#                            Zone 2  Power Consumption  \
# Temperature                                 0.382428
# Humidity                                   -0.294961
# Wind Speed                                  0.146413
# general diffuse flows                       0.157223
# diffuse flows                               0.044667
# Zone 1 Power Consumption                    0.834519
# Zone 2  Power Consumption                   1.000000
# Zone 3  Power Consumption                   0.570932
#
#                            Zone 3  Power Consumption
# Temperature                                 0.489527
# Humidity                                   -0.233022
# Wind Speed                                  0.278641
# general diffuse flows                       0.063376
# diffuse flows                              -0.038506
# Zone 1 Power Consumption                    0.750733
# Zone 2  Power Consumption                   0.570932
# Zone 3  Power Consumption                   1.000000

# %%
df.isnull().sum()
# Out:
# DateTime                     0
# Temperature                  0
# Humidity                     0
# Wind Speed                   0
# general diffuse flows        0
# diffuse flows                0
# Zone 1 Power Consumption     0
# Zone 2  Power Consumption    0
# Zone 3  Power Consumption    0
# dtype: int64

# %%
df.hist(bins=50, figsize=(20,15))
plt.show()

# %%
corr_matrix = df.corr()

corr_matrix['Zone 1 Power Consumption'].sort_values(ascending=False)
# Out:
# C:\Users\tanto\AppData\Local\Temp\ipykernel_23184\104650478.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df.corr()
# Zone 1 Power Consumption     1.000000
# Zone 2  Power Consumption    0.834519
# Zone 3  Power Consumption    0.750733
# Temperature                  0.440221
# general diffuse flows        0.187965
# Wind Speed                   0.167444
# diffuse flows                0.080274
# Humidity                    -0.287421
# Name: Zone 1 Power Consumption, dtype: float64

# %%
# visualize the correlation matrix
plt.figure()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()

# %%
df.head()
# Out:
#         DateTime  Temperature  Humidity  Wind Speed  general diffuse flows  \
# 0  1/1/2017 0:00        6.559      73.8       0.083                  0.051
# 1  1/1/2017 0:10        6.414      74.5       0.083                  0.070
# 2  1/1/2017 0:20        6.313      74.5       0.080                  0.062
# 3  1/1/2017 0:30        6.121      75.0       0.083                  0.091
# 4  1/1/2017 0:40        5.921      75.7       0.081                  0.048
#
#    diffuse flows  Zone 1 Power Consumption  Zone 2  Power Consumption  \
# 0          0.119               34055.69620                16128.87538
# 1          0.085               29814.68354                19375.07599
# 2          0.100               29128.10127                19006.68693
# 3          0.096               28228.86076                18361.09422
# 4          0.085               27335.69620                17872.34043
#
#    Zone 3  Power Consumption
# 0                20240.96386
# 1                20131.08434
# 2                19668.43373
# 3                18899.27711
# 4                18442.40964

# %%
# convert the date_time column to a datetime datatype
df['DateTime'] = pd.to_datetime(df['DateTime'])

# %%
# drop Zone 2 and Zone 3 columns, as we are only interested in Zone 1
df = df.drop(columns=['Zone 2  Power Consumption', 'Zone 3  Power Consumption'])

df.head()
# Out:
#              DateTime  Temperature  Humidity  Wind Speed  \
# 0 2017-01-01 00:00:00        6.559      73.8       0.083
# 1 2017-01-01 00:10:00        6.414      74.5       0.083
# 2 2017-01-01 00:20:00        6.313      74.5       0.080
# 3 2017-01-01 00:30:00        6.121      75.0       0.083
# 4 2017-01-01 00:40:00        5.921      75.7       0.081
#
#    general diffuse flows  diffuse flows  Zone 1 Power Consumption
# 0                  0.051          0.119               34055.69620
# 1                  0.070          0.085               29814.68354
# 2                  0.062          0.100               29128.10127
# 3                  0.091          0.096               28228.86076
# 4                  0.048          0.085               27335.69620

# %%
df.head()
# Out:
#              DateTime  Temperature  Humidity  Wind Speed  \
# 0 2017-01-01 00:00:00        6.559      73.8       0.083
# 1 2017-01-01 00:10:00        6.414      74.5       0.083
# 2 2017-01-01 00:20:00        6.313      74.5       0.080
# 3 2017-01-01 00:30:00        6.121      75.0       0.083
# 4 2017-01-01 00:40:00        5.921      75.7       0.081
#
#    general diffuse flows  diffuse flows  Zone 1 Power Consumption
# 0                  0.051          0.119               34055.69620
# 1                  0.070          0.085               29814.68354
# 2                  0.062          0.100               29128.10127
# 3                  0.091          0.096               28228.86076
# 4                  0.048          0.085               27335.69620

# %%
df['Day'] = df['DateTime'].dt.day
df['Month'] = df['DateTime'].dt.month
df['Hour'] = df['DateTime'].dt.hour
df['Minute'] = df['DateTime'].dt.minute
df['Day of Week'] = df['DateTime'].dt.dayofweek + 1

# %%
df.head()
# Out:
#              DateTime  Temperature  Humidity  Wind Speed  \
# 0 2017-01-01 00:00:00        6.559      73.8       0.083
# 1 2017-01-01 00:10:00        6.414      74.5       0.083
# 2 2017-01-01 00:20:00        6.313      74.5       0.080
# 3 2017-01-01 00:30:00        6.121      75.0       0.083
# 4 2017-01-01 00:40:00        5.921      75.7       0.081
#
#    general diffuse flows  diffuse flows  Zone 1 Power Consumption  Day  Month  \
# 0                  0.051          0.119               34055.69620    1      1
# 1                  0.070          0.085               29814.68354    1      1
# 2                  0.062          0.100               29128.10127    1      1
# 3                  0.091          0.096               28228.86076    1      1
# 4                  0.048          0.085               27335.69620    1      1
#
#    Hour  Minute  Day of Week
# 0     0       0            7
# 1     0      10            7
# 2     0      20            7
# 3     0      30            7
# 4     0      40            7

# %%
def month_to_quarter(series):
    if series['Month'] <=3:
        return 1
    elif series['Month'] >3 and series['Month'] <=6:
        return 2
    elif series['Month'] >6 and series['Month'] <=9:
        return 3
    elif series['Month'] >9 and series['Month'] <=12:
        return 4

# %%
df['Quarter of Year'] = df.apply(month_to_quarter, axis='columns')
df['Day of Year'] = df['DateTime'].dt.strftime('%j').astype(int)  
df = df.drop(['DateTime'],axis=1)

# %%
df.columns
# Out:
# Index(['Temperature', 'Humidity', 'Wind Speed', 'general diffuse flows',
#        'diffuse flows', 'Zone 1 Power Consumption', 'Day', 'Month', 'Hour',
#        'Minute', 'Day of Week', 'Quarter of Year', 'Day of Year'],
#       dtype='object')

# %%
df = df[['Temperature', 'Humidity', 'Wind Speed', 'general diffuse flows',
       'diffuse flows', 'Day', 'Month', 'Hour',
       'Minute', 'Day of Week', 'Quarter of Year', 'Day of Year','Zone 1 Power Consumption']]

# %%
df.head()
# Out:
#    Temperature  Humidity  Wind Speed  general diffuse flows  diffuse flows  \
# 0        6.559      73.8       0.083                  0.051          0.119
# 1        6.414      74.5       0.083                  0.070          0.085
# 2        6.313      74.5       0.080                  0.062          0.100
# 3        6.121      75.0       0.083                  0.091          0.096
# 4        5.921      75.7       0.081                  0.048          0.085
#
#    Day  Month  Hour  Minute  Day of Week  Quarter of Year  Day of Year  \
# 0    1      1     0       0            7                1            1
# 1    1      1     0      10            7                1            1
# 2    1      1     0      20            7                1            1
# 3    1      1     0      30            7                1            1
# 4    1      1     0      40            7                1            1
#
#    Zone 1 Power Consumption
# 0               34055.69620
# 1               29814.68354
# 2               29128.10127
# 3               28228.86076
# 4               27335.69620

# %%
corr = df.corr().round(decimals=3)
mask = np.triu(np.ones_like(corr, dtype=np.bool))
f, ax = plt.subplots(figsize=(20, 20))
cmap = sns.diverging_palette(240, 10, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=None, center=0,square=True, annot=True, linewidths=.5, cbar_kws={"shrink": .9})
# Out:
# C:\Users\tanto\AppData\Local\Temp\ipykernel_23184\4082589296.py:2: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.triu(np.ones_like(corr, dtype=np.bool))
# <Axes: >

# %%
fig, ax = plt.subplots(figsize=(20, 10))

zone1 = sns.boxplot(data=df, x='Hour', y='Zone 1 Power Consumption', palette = 'Blues', showfliers=False)

plt.suptitle('KW by Hour', fontsize=15)
plt.xlabel('hour', fontsize=12)
plt.ylabel('Power Consumption in KW', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.show()
# Out:
# C:\Users\tanto\AppData\Local\Temp\ipykernel_23184\4075097970.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   zone1 = sns.boxplot(data=df, x='Hour', y='Zone 1 Power Consumption', palette = 'Blues', showfliers=False)

# %%
fig, ax = plt.subplots(figsize=(20, 10))

sns.boxplot(data=df, x='Hour', y='Temperature', palette = 'Reds', showfliers=False)

plt.suptitle('Temperature by Hour', fontsize=15)
plt.xlabel('hour', fontsize=12)
plt.ylabel('Temperature in °C', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.show()
# Out:
# C:\Users\tanto\AppData\Local\Temp\ipykernel_23184\2944371273.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Hour', y='Temperature', palette = 'Reds', showfliers=False)

# %%
fig, ax = plt.subplots(figsize=(20, 10))

sns.boxplot(data=df, x='Hour', y='Humidity', palette = 'Greens', showfliers=False)

plt.suptitle('Humidity by Hour', fontsize=15)
plt.xlabel('hour', fontsize=12)
plt.ylabel('Humidity in %', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.show()
# Out:
# C:\Users\tanto\AppData\Local\Temp\ipykernel_23184\128259617.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Hour', y='Humidity', palette = 'Greens', showfliers=False)

# %% [markdown]
# ## Split Train and Test Data

# %%
train_size = int(len(df) * 0.8)
train_df = df[:train_size]
test_df = df[train_size:]

# Visualize the split
fig, ax = plt.subplots(figsize=(25, 8))

# Plotting power consumption to visualize split
ax.plot(train_df.index, train_df['Zone 1 Power Consumption'], label='Training Set', color='darkorange')
ax.plot(test_df.index, test_df['Zone 1 Power Consumption'], label='Test Set', color='yellowgreen')

# Mark the point of split
ax.axvline(train_size, color='black', linestyle='--')

# Add legend, labels, and title
ax.legend(['Training Set', 'Test Set'])
plt.title('Data Train/Test Split', fontsize=15)
plt.xlabel('Index', fontsize=12)
plt.ylabel('Power Consumption in KW', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Display the plot
plt.show()

# %%
train_df
# Out:
#        Temperature  Humidity  Wind Speed  general diffuse flows  \
# 0            6.559      73.8       0.083                  0.051
# 1            6.414      74.5       0.083                  0.070
# 2            6.313      74.5       0.080                  0.062
# 3            6.121      75.0       0.083                  0.091
# 4            5.921      75.7       0.081                  0.048
# ...            ...       ...         ...                    ...
# 41927       17.570      93.3       0.139                  0.084
# 41928       17.580      93.3       0.094                  0.091
# 41929       17.540      93.4       0.082                  0.077
# 41930       17.570      93.3       0.084                  0.091
# 41931       17.630      93.4       0.083                  0.059
#
#        diffuse flows  Day  Month  Hour  Minute  Day of Week  Quarter of Year  \
# 0              0.119    1      1     0       0            7                1
# 1              0.085    1      1     0      10            7                1
# 2              0.100    1      1     0      20            7                1
# 3              0.096    1      1     0      30            7                1
# 4              0.085    1      1     0      40            7                1
# ...              ...  ...    ...   ...     ...          ...              ...
# 41927          0.107   19     10     3      50            4                4
# 41928          0.115   19     10     4       0            4                4
# 41929          0.152   19     10     4      10            4                4
# 41930          0.107   19     10     4      20            4                4
# 41931          0.130   19     10     4      30            4                4
#
#        Day of Year  Zone 1 Power Consumption
# 0                1               34055.69620
# 1                1               29814.68354
# 2                1               29128.10127
# 3                1               28228.86076
# 4                1               27335.69620
# ...            ...                       ...
# 41927          292               24924.28884
# 41928          292               25094.44201
# 41929          292               25390.63457
# 41930          292               25371.72867
# 41931          292               25554.48578
#
# [41932 rows x 13 columns]

# %%
test_df
# Out:
#        Temperature  Humidity  Wind Speed  general diffuse flows  \
# 41932       17.830      93.6       0.084                  0.077
# 41933       17.970      93.4       0.091                  0.084
# 41934       17.980      93.3       0.092                  0.095
# 41935       18.000      93.4       0.094                  0.073
# 41936       18.040      93.4       0.071                  0.102
# ...            ...       ...         ...                    ...
# 52411        7.010      72.4       0.080                  0.040
# 52412        6.947      72.6       0.082                  0.051
# 52413        6.900      72.8       0.086                  0.084
# 52414        6.758      73.0       0.080                  0.066
# 52415        6.580      74.1       0.081                  0.062
#
#        diffuse flows  Day  Month  Hour  Minute  Day of Week  Quarter of Year  \
# 41932          0.130   19     10     4      40            4                4
# 41933          0.144   19     10     4      50            4                4
# 41934          0.078   19     10     5       0            4                4
# 41935          0.130   19     10     5      10            4                4
# 41936          0.100   19     10     5      20            4                4
# ...              ...  ...    ...   ...     ...          ...              ...
# 52411          0.096   30     12    23      10            6                4
# 52412          0.093   30     12    23      20            6                4
# 52413          0.074   30     12    23      30            6                4
# 52414          0.089   30     12    23      40            6                4
# 52415          0.111   30     12    23      50            6                4
#
#        Day of Year  Zone 1 Power Consumption
# 41932          292               25573.39168
# 41933          292               25686.82713
# 41934          292               26537.59300
# 41935          292               26928.31510
# 41936          292               26758.16193
# ...            ...                       ...
# 52411          364               31160.45627
# 52412          364               30430.41825
# 52413          364               29590.87452
# 52414          364               28958.17490
# 52415          364               28349.80989
#
# [10484 rows x 13 columns]

# %%
X_train = train_df.drop(['Zone 1 Power Consumption'], axis=1)
y_train = train_df['Zone 1 Power Consumption']

# %%
X_train
# Out:
#        Temperature  Humidity  Wind Speed  general diffuse flows  \
# 0            6.559      73.8       0.083                  0.051
# 1            6.414      74.5       0.083                  0.070
# 2            6.313      74.5       0.080                  0.062
# 3            6.121      75.0       0.083                  0.091
# 4            5.921      75.7       0.081                  0.048
# ...            ...       ...         ...                    ...
# 41927       17.570      93.3       0.139                  0.084
# 41928       17.580      93.3       0.094                  0.091
# 41929       17.540      93.4       0.082                  0.077
# 41930       17.570      93.3       0.084                  0.091
# 41931       17.630      93.4       0.083                  0.059
#
#        diffuse flows  Day  Month  Hour  Minute  Day of Week  Quarter of Year  \
# 0              0.119    1      1     0       0            7                1
# 1              0.085    1      1     0      10            7                1
# 2              0.100    1      1     0      20            7                1
# 3              0.096    1      1     0      30            7                1
# 4              0.085    1      1     0      40            7                1
# ...              ...  ...    ...   ...     ...          ...              ...
# 41927          0.107   19     10     3      50            4                4
# 41928          0.115   19     10     4       0            4                4
# 41929          0.152   19     10     4      10            4                4
# 41930          0.107   19     10     4      20            4                4
# 41931          0.130   19     10     4      30            4                4
#
#        Day of Year
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1
# ...            ...
# 41927          292
# 41928          292
# 41929          292
# 41930          292
# 41931          292
#
# [41932 rows x 12 columns]

# %%
y_train
# Out:
# 0        34055.69620
# 1        29814.68354
# 2        29128.10127
# 3        28228.86076
# 4        27335.69620
#             ...
# 41927    24924.28884
# 41928    25094.44201
# 41929    25390.63457
# 41930    25371.72867
# 41931    25554.48578
# Name: Zone 1 Power Consumption, Length: 41932, dtype: float64

# %%
X_test = test_df.drop(['Zone 1 Power Consumption'], axis=1)
y_test = test_df['Zone 1 Power Consumption']

# %%
X_test
# Out:
#        Temperature  Humidity  Wind Speed  general diffuse flows  \
# 41932       17.830      93.6       0.084                  0.077
# 41933       17.970      93.4       0.091                  0.084
# 41934       17.980      93.3       0.092                  0.095
# 41935       18.000      93.4       0.094                  0.073
# 41936       18.040      93.4       0.071                  0.102
# ...            ...       ...         ...                    ...
# 52411        7.010      72.4       0.080                  0.040
# 52412        6.947      72.6       0.082                  0.051
# 52413        6.900      72.8       0.086                  0.084
# 52414        6.758      73.0       0.080                  0.066
# 52415        6.580      74.1       0.081                  0.062
#
#        diffuse flows  Day  Month  Hour  Minute  Day of Week  Quarter of Year  \
# 41932          0.130   19     10     4      40            4                4
# 41933          0.144   19     10     4      50            4                4
# 41934          0.078   19     10     5       0            4                4
# 41935          0.130   19     10     5      10            4                4
# 41936          0.100   19     10     5      20            4                4
# ...              ...  ...    ...   ...     ...          ...              ...
# 52411          0.096   30     12    23      10            6                4
# 52412          0.093   30     12    23      20            6                4
# 52413          0.074   30     12    23      30            6                4
# 52414          0.089   30     12    23      40            6                4
# 52415          0.111   30     12    23      50            6                4
#
#        Day of Year
# 41932          292
# 41933          292
# 41934          292
# 41935          292
# 41936          292
# ...            ...
# 52411          364
# 52412          364
# 52413          364
# 52414          364
# 52415          364
#
# [10484 rows x 12 columns]

# %%
y_test
# Out:
# 41932    25573.39168
# 41933    25686.82713
# 41934    26537.59300
# 41935    26928.31510
# 41936    26758.16193
#             ...
# 52411    31160.45627
# 52412    30430.41825
# 52413    29590.87452
# 52414    28958.17490
# 52415    28349.80989
# Name: Zone 1 Power Consumption, Length: 10484, dtype: float64

# %%
test_df
# Out:
#        Temperature  Humidity  Wind Speed  general diffuse flows  \
# 41932       17.830      93.6       0.084                  0.077
# 41933       17.970      93.4       0.091                  0.084
# 41934       17.980      93.3       0.092                  0.095
# 41935       18.000      93.4       0.094                  0.073
# 41936       18.040      93.4       0.071                  0.102
# ...            ...       ...         ...                    ...
# 52411        7.010      72.4       0.080                  0.040
# 52412        6.947      72.6       0.082                  0.051
# 52413        6.900      72.8       0.086                  0.084
# 52414        6.758      73.0       0.080                  0.066
# 52415        6.580      74.1       0.081                  0.062
#
#        diffuse flows  Day  Month  Hour  Minute  Day of Week  Quarter of Year  \
# 41932          0.130   19     10     4      40            4                4
# 41933          0.144   19     10     4      50            4                4
# 41934          0.078   19     10     5       0            4                4
# 41935          0.130   19     10     5      10            4                4
# 41936          0.100   19     10     5      20            4                4
# ...              ...  ...    ...   ...     ...          ...              ...
# 52411          0.096   30     12    23      10            6                4
# 52412          0.093   30     12    23      20            6                4
# 52413          0.074   30     12    23      30            6                4
# 52414          0.089   30     12    23      40            6                4
# 52415          0.111   30     12    23      50            6                4
#
#        Day of Year  Zone 1 Power Consumption
# 41932          292               25573.39168
# 41933          292               25686.82713
# 41934          292               26537.59300
# 41935          292               26928.31510
# 41936          292               26758.16193
# ...            ...                       ...
# 52411          364               31160.45627
# 52412          364               30430.41825
# 52413          364               29590.87452
# 52414          364               28958.17490
# 52415          364               28349.80989
#
# [10484 rows x 13 columns]

# %%
test_df
# Out:
#        Temperature  Humidity  Wind Speed  general diffuse flows  \
# 41932       17.830      93.6       0.084                  0.077
# 41933       17.970      93.4       0.091                  0.084
# 41934       17.980      93.3       0.092                  0.095
# 41935       18.000      93.4       0.094                  0.073
# 41936       18.040      93.4       0.071                  0.102
# ...            ...       ...         ...                    ...
# 52411        7.010      72.4       0.080                  0.040
# 52412        6.947      72.6       0.082                  0.051
# 52413        6.900      72.8       0.086                  0.084
# 52414        6.758      73.0       0.080                  0.066
# 52415        6.580      74.1       0.081                  0.062
#
#        diffuse flows  Day  Month  Hour  Minute  Day of Week  Quarter of Year  \
# 41932          0.130   19     10     4      40            4                4
# 41933          0.144   19     10     4      50            4                4
# 41934          0.078   19     10     5       0            4                4
# 41935          0.130   19     10     5      10            4                4
# 41936          0.100   19     10     5      20            4                4
# ...              ...  ...    ...   ...     ...          ...              ...
# 52411          0.096   30     12    23      10            6                4
# 52412          0.093   30     12    23      20            6                4
# 52413          0.074   30     12    23      30            6                4
# 52414          0.089   30     12    23      40            6                4
# 52415          0.111   30     12    23      50            6                4
#
#        Day of Year  Zone 1 Power Consumption
# 41932          292               25573.39168
# 41933          292               25686.82713
# 41934          292               26537.59300
# 41935          292               26928.31510
# 41936          292               26758.16193
# ...            ...                       ...
# 52411          364               31160.45627
# 52412          364               30430.41825
# 52413          364               29590.87452
# 52414          364               28958.17490
# 52415          364               28349.80989
#
# [10484 rows x 13 columns]

# %% [markdown]
# ## Train

# %%
from sklearn.ensemble import RandomForestRegressor

rf1 = RandomForestRegressor(n_estimators=700, min_samples_split=2, min_samples_leaf=1,max_features=3)
rf1.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_features=3, n_estimators=700)

# %%
predictions = rf1.predict(X_train)

# %%
print('Predictions:')
y_pred = rf1.predict(X_test)
print(y_pred[:10])

print('Actual Values:')
print(y_test[:10].values)
# Out:
# Predictions:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[256], line 2
#       1 print('Predictions:')
# ----> 2 y_pred = rf1.predict(X_test)
#       3 print(y_pred[:10])
#       5 print('Actual Values:')
#
# File c:\Users\tanto\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_forest.py:997, in ForestRegressor.predict(self, X)
#     995 # Parallel loop
#     996 lock = threading.Lock()
# --> 997 Parallel(n_jobs=n_jobs, verbose=self.verbose, require="sharedmem")(
#     998     delayed(_accumulate_prediction)(e.predict, X, [y_hat], lock)
#     999     for e in self.estimators_
#    1000 )
#    1002 y_hat /= len(self.estimators_)
#    1004 return y_hat
#
# File c:\Users\tanto\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\parallel.py:65, in Parallel.__call__(self, iterable)
#      60 config = get_config()
#      61 iterable_with_config = (
#      62     (_with_config(delayed_func, config), args, kwargs)
#      63     for delayed_func, args, kwargs in iterable
#      64 )
# ---> 65 return super().__call__(iterable_with_config)
#
# File c:\Users\tanto\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\parallel.py:1863, in Parallel.__call__(self, iterable)
#    1861     output = self._get_sequential_output(iterable)
#    1862     next(output)
# -> 1863     return output if self.return_generator else list(output)
#    1865 # Let's create an ID that uniquely identifies the current call. If the
#    1866 # call is interrupted early and that the same instance is immediately
#    1867 # re-used, this id will be used to prevent workers that were
#    1868 # concurrently finalizing a task from the previous call to run the
#    1869 # callback.
#    1870 with self._lock:
#
# File c:\Users\tanto\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\parallel.py:1792, in Parallel._get_sequential_output(self, iterable)
#    1790 self.n_dispatched_batches += 1
#    1791 self.n_dispatched_tasks += 1
# -> 1792 res = func(*args, **kwargs)
#    1793 self.n_completed_tasks += 1
#    1794 self.print_progress()
#
# File c:\Users\tanto\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\parallel.py:127, in _FuncWrapper.__call__(self, *args, **kwargs)
#     125     config = {}
#     126 with config_context(**config):
# --> 127     return self.function(*args, **kwargs)
#
# File c:\Users\tanto\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_forest.py:647, in _accumulate_prediction(predict, X, out, lock)
#     640 def _accumulate_prediction(predict, X, out, lock):
#     641     """
#     642     This is a utility function for joblib's Parallel.
#     643
#     644     It can't go locally in ForestClassifier or ForestRegressor, because joblib
#     645     complains that it cannot pickle it when placed there.
#     646     """
# --> 647     prediction = predict(X, check_input=False)
#     648     with lock:
#     649         if len(out) == 1:
#
# File c:\Users\tanto\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\tree\_classes.py:501, in BaseDecisionTree.predict(self, X, check_input)
#     499 check_is_fitted(self)
#     500 X = self._validate_X_predict(X, check_input)
# --> 501 proba = self.tree_.predict(X)
#     502 n_samples = X.shape[0]
#     504 # Classification
#
# KeyboardInterrupt:

# %%
plt.figure(figsize=(25, 8))
plt.plot(y_test.index[:1000], y_test.values[:1000], label='Actual Values', color='blue')
plt.plot(y_test.index[:1000], y_pred[:1000], label='Predictions', linestyle='--', color='orange')

plt.title('True Data vs Predictions', fontsize=15)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Power Consumption in KW', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(fontsize=12)

plt.show()
